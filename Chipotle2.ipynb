# %% [markdown]
# # 1. import libraries and file

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
file_path = './chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t' )

# %% [markdown]
# # 2. Total revenue top 10

# %%
#raw data overview
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#type convert : chipo['item_price'] string into double
chipo['item_price'] = chipo['item_price'].apply(lambda x:float(x[1:]))

# %%
#creating new column named 'revenue'
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# ...

# %%
#group by item_name
#get the sum of revenue
total_revenue = chipo.groupby('item_name')['revenue'].sum()
total_revenue
# Out:
# item_name
# 6 Pack Soft Drink                         369.93
# Barbacoa Bowl                             672.36
# Barbacoa Burrito                          894.75
# Barbacoa Crispy Tacos                     138.71
# Barbacoa Salad Bowl                       106.40
# Barbacoa Soft Tacos                       250.46
# Bottled Water                             649.18
# Bowl                                       74.00
# Burrito                                    44.40
# Canned Soda                               191.84
# Canned Soft Drink                         603.75
# Carnitas Bowl                             830.71
# Carnitas Burrito                          616.33
# Carnitas Crispy Tacos                      95.94
# Carnitas Salad                              8.99
# Carnitas Salad Bowl                        66.34
# Carnitas Soft Tacos                       375.94
# Chicken Bowl                             8044.63
# Chicken Burrito                          6387.06
# ...

# %%
#sort in descending order
total_revenue.sort_values(ascending = False)
# Out:
# item_name
# Chicken Bowl                             8044.63
# Chicken Burrito                          6387.06
# Steak Burrito                            4236.13
# Steak Bowl                               2479.81
# Chips and Guacamole                      2475.62
# Chicken Salad Bowl                       1506.25
# Chicken Soft Tacos                       1199.01
# Chips and Fresh Tomato Salsa             1033.96
# Veggie Burrito                           1002.27
# Veggie Bowl                               901.95
# Barbacoa Burrito                          894.75
# Carnitas Bowl                             830.71
# Barbacoa Bowl                             672.36
# Bottled Water                             649.18
# Carnitas Burrito                          616.33
# Canned Soft Drink                         603.75
# Chips                                     580.34
# Steak Soft Tacos                          554.55
# Chicken Crispy Tacos                      524.11
# ...

# %%
#take the top 10
total_revenue.sort_values(ascending = False)[:10]
# Out:
# item_name
# Chicken Bowl                    8044.63
# Chicken Burrito                 6387.06
# Steak Burrito                   4236.13
# Steak Bowl                      2479.81
# Chips and Guacamole             2475.62
# Chicken Salad Bowl              1506.25
# Chicken Soft Tacos              1199.01
# Chips and Fresh Tomato Salsa    1033.96
# Veggie Burrito                  1002.27
# Veggie Bowl                      901.95
# Name: revenue, dtype: float64

# %%
#adding 'top+i' statement using for loop
top_10_revenue = total_revenue.sort_values(ascending = False)[:10]

# %%
top_10_revenue.index
# Out:
# Index(['Chicken Bowl', 'Chicken Burrito', 'Steak Burrito', 'Steak Bowl',
#        'Chips and Guacamole', 'Chicken Salad Bowl', 'Chicken Soft Tacos',
#        'Chips and Fresh Tomato Salsa', 'Veggie Burrito', 'Veggie Bowl'],
#       dtype='object', name='item_name')

# %%
top_10_revenue.values
# Out:
# array([8044.63, 6387.06, 4236.13, 2479.81, 2475.62, 1506.25, 1199.01,
#        1033.96, 1002.27,  901.95])

# %%
print('< 10 Items with Highest Revenue >')
for i in range(10):
    print('Top', i+1, top_10_revenue.index[i], '\t', '$', top_10_revenue.values[i])
# Out:
# < 10 Items with Highest Revenue >
# Top 1 Chicken Bowl 	 $ 8044.629999999975
# Top 2 Chicken Burrito 	 $ 6387.059999999984
# Top 3 Steak Burrito 	 $ 4236.12999999999
# Top 4 Steak Bowl 	 $ 2479.8099999999995
# Top 5 Chips and Guacamole 	 $ 2475.6199999999963
# Top 6 Chicken Salad Bowl 	 $ 1506.25
# Top 7 Chicken Soft Tacos 	 $ 1199.0100000000002
# Top 8 Chips and Fresh Tomato Salsa 	 $ 1033.9600000000003
# Top 9 Veggie Burrito 	 $ 1002.2700000000003
# Top 10 Veggie Bowl 	 $ 901.9500000000002

# %% [markdown]
# -----
# # 3. Average payment per order

# %%
#quick look over raw data
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# ...

# %%
#group by order_id
#sum of revenue
chipo.groupby('order_id')['revenue'].sum()
# Out:
# order_id
# 1       11.56
# 2       33.96
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: revenue, Length: 1834, dtype: float64

# %%
payment_per_id = chipo.groupby('order_id')['revenue'].sum()

# %%
#get the average
payment_per_id.mean()
# Out:
# 21.39423118865867

# %% [markdown]
# -----
# # 4. Most ordered items

# %%
#raw data overview
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# ...

# %%
#group by item_name
#count order_id
chipo.groupby('item_name')['order_id'].count()
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
#sort in descending order
chipo.groupby('item_name')['order_id'].count().sort_values(ascending = False)
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# -----
# # 5. order_id list of orders over 50 dollars

# %%
#raw data overview
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# ...

# %%
#change column name 'revenue' into 'revenue=order amount'
chipo['revenue&order_amount'] = chipo['revenue']
chipo.drop('revenue', axis = 1, inplace = True)
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
#group by order_id
#get the sum of order amount per order id
chipo.groupby('order_id')['revenue&order_amount'].sum()
# Out:
# order_id
# 1       11.56
# 2       33.96
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: revenue&order_amount, Length: 1834, dtype: float64

# %%
#print type
type(order_amount_per_id)
# Out:
# pandas.core.series.Series

# %%
#add condition and extract results
order_amount_per_id[order_amount_per_id>50]
result = order_amount_per_id[order_amount_per_id>50]
print(result.index)
print(result.index.size)
# Out:
# Int64Index([  96,  103,  178,  193,  195,  205,  343,  481,  488,  491,  511,
#              561,  577,  616,  635,  691,  708,  737,  759,  818,  823,  848,
#              916,  926,  947,  953,  973, 1006, 1051, 1170, 1182, 1336, 1360,
#             1398, 1443, 1449, 1454, 1462, 1483, 1533, 1559, 1586, 1592, 1655,
#             1660, 1718, 1719, 1738, 1764, 1786, 1825],
#            dtype='int64', name='order_id')
# 51

# %% [markdown]
# -----
# # 6. Ordered items in the order with highest order amount

# %%
#raw data quick view
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
#group by id
#sum of order_amount
#sort in descending order
chipo.groupby('order_id')
chipo.groupby('order_id')['revenue&order_amount'].sum()
chipo.groupby('order_id')['revenue&order_amount'].sum().sort_values(ascending = False)
# Out:
# order_id
# 1443    1074.24
# 511      315.29
# 1559     246.00
# 1660     222.75
# 926      205.25
#          ...
# 393       10.08
# 1436      10.08
# 388       10.08
# 1467      10.08
# 113       10.08
# Name: revenue&order_amount, Length: 1834, dtype: float64

# %%
#order with highest order amount
highest_order = chipo.groupby('order_id')['revenue&order_amount'].sum().sort_values(ascending = False).index[0]
highest_order
# Out:
# 1443

# %%
#extract rows with id=1443
chipo[chipo['order_id'] == 1443]
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3599      1443         7                 Bottled Water
# 3600      1443         1             6 Pack Soft Drink
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 3603      1443         3                 Steak Burrito
# 3604      1443         2                 Bottled Water
#
#                                      choice_description  item_price  \
# 3598                                                NaN       44.25
# 3599                                                NaN       10.50
# 3600                                             [Coke]        6.49
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       27.75
# ...

# %%
#extract items
id1443 = chipo[chipo['order_id'] == 1443]
id1443['item_name'].values
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Bottled Water',
#        '6 Pack Soft Drink', 'Veggie Burrito', 'Chicken Burrito',
#        'Steak Burrito', 'Bottled Water'], dtype=object)

# %% [markdown]
# -----
# # 7. Number of veggie salad bowl orders

# %%
#raw data quick look
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
#extract veggie salad bowl
chipo[chipo['item_name'] == 'Veggie Salad Bowl']
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price  \
# ...

# %%
#extract 'order_id' column
#count rows
vsb = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
vsb['order_id'].count()
# Out:
# 18

# %% [markdown]
# -----
# # 8. Number of ordering more than two chicken bowl

# %%
#raw data quick view
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
#extract chicken bowl
chipo[chipo['item_name'] == 'Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
#extract column 'quantity'
#extract rows where quantity >= 2
cb = chipo[chipo['item_name'] == 'Chicken Bowl']
cb['quantity'] >= 2
# Out:
# 4        True
# 5       False
# 13      False
# 19      False
# 26      False
#         ...
# 4590    False
# 4591    False
# 4595    False
# 4599    False
# 4604    False
# Name: quantity, Length: 726, dtype: bool

# %%
#count
cb[cb['quantity'] >= 2]['quantity'].size
# Out:
# 33
